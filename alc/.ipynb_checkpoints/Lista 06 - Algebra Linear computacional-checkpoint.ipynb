# %% [markdown]
# ## Questão 01
#
# Número de condição de uma matriz é: <br>
# ![image.png](attachment:image.png)
#
# onde || . || é uma norma matricial qualquer

# %% [markdown]
# Lembrando que Norma 1 é ![image.png](attachment:image.png)

# %% [markdown]
# ||A||1 = 13 e ||A^1||1 = 8
#
# condição(A) = k (A) = 13 * 8 = 104
#
# A matriz é bem condicionada já que 104 < 10^6

# %% [markdown]
# b) Norma infinito
# ![image.png](attachment:image.png)

# %% [markdown]
# ||A|| = 17 e ||A^1|| = 2
#
# condição(A) = k (A) = 17 * 6 = 102
#
# A matriz é bem condicionada, 102 < 10^6

# %% [markdown]
# ## Questão 02

# %% [markdown]
# f(0) = 0.5 <br>
# f(1) = 2.5 <br>
# f(2) = 4.5 <br>
# f(3) = 6.5 <br>
# f(4) = 8.5 <br>

# %% [markdown]
# (a) Erro máximo ![image.png](attachment:image.png)

# %% [markdown]
# E = max {0.5 - 0.523, 2.5 - 3.275, 4.5 - 4.319, 6.5 - 5.511, 8.5 - 8.052}
# E = max {-0.023, -0.775, 0.181, 0.989, 0.448}
# E = 0,989

# %% [markdown]
# (b) Erro médio
# ![image.png](attachment:image.png)

# %% [markdown]
# E1 = 1/n (-0.023 + -0.775 + 0.181 + 0.989 + 0.448) = <br>
# 1/4 (0.82) = <br>
# 0.205

# %% [markdown]
# (C) Raiz do erro médio quadrático
# ![image.png](attachment:image.png)

# %% [markdown]
# E2 = sqrt { 1/n ((-0.023)^2 + (-0.775)^2 + (0.181)^2 + (0.989)^2 + (0.448)^2) } <br>
# E2 = sqrt { 1/4 * 1.8127400000000002 } <br>
# E2 = sqrt { 0.45318500000000006 } <br>
# E2 = 0.22659250000000003 <br>

# %%
E2 = ( (-0.023)**2 + (-0.775)**2 + (0.181)**2 + (0.989)**2 + (0.448)**2 )
E2 = 1/4 * E2 
E2 = E2 ** 1/2
print(E2) #tirando a prova
# Out:
# 0.22659250000000003

# %% [markdown]
# ## Questão 03

# %% [markdown]
# (a)

# %% [markdown]
# (b) Queremos minimizar ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Questão 04

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [2.0, 3.5, 4.0, 5.1, 7.0]
y = [2.2, 2.0, 3.0, 6.0, 5.0]

scatter_plot = plt.scatter(x, y)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Fonte = https://www.dca.ufrn.br/~diogo/FTP/dca0304/ajustedecurvas.pdf ESSA FONTE É MARAVILHOSA LEIAM

# %% [markdown]
# Σ xi= 2.0 + 3.5 + 4.0 + 5.1 + 7.0 = 21.6
#
# Σ xi^2= 2.0^2 + 3.5^2 + 4.0^2 + 5.1^2 + 7.0^2 = 4 + 12.25 + 16 + 26.01 + 49 = 107.26
#
# Σ yi = 2.2 + 2.0 + 3.0 + 6.0 + 5.0 = 18.2
#
# Σ xi * yi = 2.0*2.2 + 3.5*2.0 + 4.0*3.0 + 5.1*6.0 + 7.0*5.0 = 4.4 + 7 + 12 + 30.6 + 35 = 89
#
# Substituindo na fôrmula:
#
# b1 = ( 5 * 89 - 21.6 * 18.2 )/ (5 * 107.26 - (21.6)^2) =
# (445 - 393.12) / (536.3 - 466.56) =
# 51.88 / 69.74 =
# 0.743906
#
#
# b0 = 18.2 - (21.6)*0.743906 / 5 =
#
# 18.2 - 16.06837 / 5 =
#
# 0.426326
#
# Resultado -> f(x) = β0 +β1x -> 0.426326 + 0.743906 x

# %% [markdown]
# ## Questão 05

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# x1 = x e x2 = ln x, então:
#
# x1 = 1, 2, 3, 4, 5, 6
# x2 = 0, 0.6931, 1,0986, 1.3862, 1.6094
# y = -4.501, 83.453, 112.953, 123.824, 170.335, 183.008
#
# Σ x1 = 1 + 2 + 3 + 4 + 5 + 6 = 21
#
# Σ x2 = 0 + 0.6931 + 1,0986 + 1.3862 + 1.6094 + 1.7917 = 6.5790
#
# Σ x1^2 = 1^2 + 2^2 + 3^2 + 4^2 + 5^2 + 6^2 = 2 + 4 + 9 + 16 + 25 + 36 = 92
#
# Σ x2 * x1 = (0 * 1) + (0.6931 * 2) + (1,0986 * 3) + (1.3862 * 4) + (1.6094 * 5) + (1.7917 * 6) = 1.3862 + 3.2958 + 5.5448 + 8.0470 + 10.7502 = 29.0240
#
# Σ x2 ^2 = 0^2 + 0.6931^2 + 1,0986^2 + 1.3862^2 + 1.6094^2 +  1.7917^2 = 0.4803 + 1.2069 + 1.9215 + 2.5901 + 3.2101 = 9.4089
#
# Σ y = -4.501 + 83.453 + 112.953 + 123.824 + 170.335 + 183.008 = 669.0720
#
# Σ y* x1 = (-4.501 * 1) + (83.453 * 2) + (112.953 * 3) + (123.824 * 4) + (170.335 * 5) + (183.008 * 6) = -4.501 + 166.9060 + 338.8590 + 495.2960 + 851.6750 + 1098.0480 = 2946.2830
#
# Σ y* x2 = -4.501 * 0 + (83.453 * 0.6931) + (112.953 * 1.0986) + (123.824 * 1.3862) + (170.335 * 1.6094) + (183.008 * 1.7917) = 0 + 57.8412 + 124.0901 + 171.6448 + 274.1371 + 327.8954 = 955.6086

# %%
import numpy as np
from numpy.linalg import solve

A = np.array([[6, 21, 6.5790],
              [21, 92, 29.0240],
              [6.5790, 29.0240, 9.4089]])

B = np.array([669.0720, 2946.2830, 955.6086])

result = solve(A, B)
print(result)
# Out:
# [  1.0973099   -0.92937342 103.66392801]

# %% [markdown]
# B1 = -0.92937342
# B2 = 103.66392801

# %% [markdown]
# ## Questão 06

# %% [markdown]
# Fonte: https://www.youtube.com/watch?v=2RgPsGuDD6I
# https://www.youtube.com/watch?v=kaL-j412a5A

# %% [markdown]
# P = 7 (ambas respostas). É mais adequeado porque possui menor desvio, passa por quase todos os pontos e por isso o erro quadratico é menor.
